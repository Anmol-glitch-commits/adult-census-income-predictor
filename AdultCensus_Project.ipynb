# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("adult_census.csv")

# %%
df
# Out:
#        Age   Profession Class  Final_census    Education   Education-num  \
# 0       39          State-gov         77516    Bachelors              13
# 1       50   Self-emp-not-inc         83311    Bachelors              13
# 2       38            Private        215646      HS-grad               9
# 3       53            Private        234721         11th               7
# 4       28            Private        338409    Bachelors              13
# ...    ...                ...           ...          ...             ...
# 32556   27            Private        257302   Assoc-acdm              12
# 32557   40            Private        154374      HS-grad               9
# 32558   58            Private        151910      HS-grad               9
# 32559   22            Private        201490      HS-grad               9
# 32560   52       Self-emp-inc        287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
#shape of the dataframe
df.shape
# Out:
# (32561, 16)

# %%
#firstly let'see the data...
df.head(10)
df.tail(10)
# Out:
#        Age Profession Class  Final_census      Education   Education-num  \
# 32551   32          Private         34066           10th               6
# 32552   43          Private         84661      Assoc-voc              11
# 32553   32          Private        116138        Masters              14
# 32554   53          Private        321865        Masters              14
# 32555   22          Private        310152   Some-college              10
# 32556   27          Private        257302     Assoc-acdm              12
# 32557   40          Private        154374        HS-grad               9
# 32558   58          Private        151910        HS-grad               9
# 32559   22          Private        201490        HS-grad               9
# 32560   52     Self-emp-inc        287927        HS-grad               9
#
#             marital-status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               32561 non-null  int64
#  1   Profession Class  32561 non-null  object
#  2   Final_census      32561 non-null  int64
#  3    Education        32561 non-null  object
#  4    Education-num    32561 non-null  int64
#  5    marital-status   32561 non-null  object
#  6    occupation       32561 non-null  object
#  7    relationship     32561 non-null  object
#  8    race             32561 non-null  object
#  9   Gender            32561 non-null  object
#  10   capital-gain     32561 non-null  int64
#  11   capital-loss     32561 non-null  int64
#  12   hours-per-week   32561 non-null  int64
#  13   country          32561 non-null  object
#  14   income           32561 non-null  object
#  15  Unnamed: 15       2 non-null      float64
# ...

# %%
df.describe()
# Out:
#                 Age  Final_census   Education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week  Unnamed: 15
# count   32561.000000     32561.000000          2.0
# mean       87.303830        40.437456      55000.0
# std       402.960219        12.347429          0.0
# min         0.000000         1.000000      55000.0
# 25%         0.000000        40.000000      55000.0
# 50%         0.000000        40.000000      55000.0
# ...

# %%
#to see the only object columns
df.select_dtypes(include="object").columns
# Out:
# Index(['Profession Class', ' Education', ' marital-status', ' occupation',
#        ' relationship', ' race', 'Gender', ' country', ' income'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'Final_census', ' Education-num', ' capital-gain',
#        ' capital-loss', ' hours-per-week', 'Unnamed: 15'],
#       dtype='object')

# %%
#Here in Unnamed: 15->there are approx 99.99% missing values are there so we can drop that feature it's irrelevant
df.isnull().sum()
(df['Unnamed: 15'].isnull().sum()/len(df))*100
# Out:
# np.float64(99.9938576825036)

# %%
#now, in some feature there are leading whitespace so remove them..
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Age', 'Profession Class', 'Final_census', 'Education', 'Education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'Gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'income',
#        'Unnamed: 15'],
#       dtype='object')

# %%
#drop unnamed : 15 column
df = df.drop(columns=['Unnamed: 15'])

# %%
#here in the profession class column there are also leading spaces...
#or in here the ' ?' ->NaN is represented by this..
df['Profession Class'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
#in each val of the column there are leading spaces..remove them
for col in df.select_dtypes(include="object"):
  print(col)
  print(df[col].unique())
# Out:
# Profession Class
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# Education
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# marital-status
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# occupation
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# relationship
# [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# race
# [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# Gender
# [' Male' ' Female']
# ...

# %%
for col in df.select_dtypes(include='object'):
  df[col] = df[col].str.strip()

# %%
#spaces removed
for col in df.select_dtypes(include="object"):
  print(col)
  print(df[col].unique())
# Out:
# Profession Class
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# Education
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# marital-status
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# occupation
# ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# relationship
# ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
# race
# ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# Gender
# ['Male' 'Female']
# country
# ...

# %%
#here in ? in profession_class is the representation of NaN
df['Profession Class'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %% [markdown]
# **? is the representation of NaN in these Columns**

# %%
df[df['Profession Class'] == "?"].shape
# Out:
# (1836, 15)

# %%
df[df['occupation'] == "?"].shape
# Out:
# (1843, 15)

# %%
df[df['country'] == "?"].shape
# Out:
# (583, 15)

# %%
#replace ? with NaN
df = df.replace('?' , np.nan)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Age                 0.000000
# Profession Class    5.638647
# Final_census        0.000000
# Education           0.000000
# Education-num       0.000000
# marital-status      0.000000
# occupation          5.660146
# relationship        0.000000
# race                0.000000
# Gender              0.000000
# capital-gain        0.000000
# capital-loss        0.000000
# hours-per-week      0.000000
# country             1.790486
# income              0.000000
# dtype: float64

# %% [markdown]
# **Will see this later on in Model Training**

# %%
#now, in profession_class , occupation , country we have replace '?' ->with NaN , Now further NaN can be imputed with Mode...
#but doing this can create bias in representation so a better way to replace is NaN with UnKnown
df['Profession Class'] = df['Profession Class'].fillna('Unknown')

# %%
df['occupation'] = df['occupation'].fillna('Unknown')

# %%
df['country'] = df['country'].fillna('Unknown')

# %% [markdown]
# **Make Categorical data more readable**

# %%
#Profession Class
profession_map = {
    'Local-gov': 'Local government',
    'Never-worked': 'Never worked',
    'Private': 'Private sector',
    'Self-emp-inc': 'Self-employed (incorporated)',
    'Self-emp-not-inc': 'Self-employed (not incorporated)',
    'State-gov': 'State government',
    'Without-pay': 'Without pay'
}

df['Profession Class'] = df['Profession Class'].replace(profession_map)

#make Occupation labels more readable
occupation_map = {
    'Handlers-cleaners': 'Handlers and Cleaners',
    'Machine-op-inspct': 'Machine Operators and Inspectors',
    'Other-service': 'Other Service',
    'Priv-house-serv': 'Private Household Service',
    'Prof-specialty': 'Professional Specialty',
    'Protective-serv': 'Protective Service',
    'Tech-support': 'Technical Support',
    'Transport-moving': 'Transportation and Moving'
}

df['occupation'] = df['occupation'].replace(occupation_map)

# Make Marital Status labels more readable
marital_map = {
    'Married-AF-spouse': 'Married (Armed Forces Spouse)',
    'Married-civ-spouse': 'Married (Civilian Spouse)'
}

df['marital-status'] = df['marital-status'].replace(marital_map)

#make Education labels more readable
education_map = {
    '1st-4th': '1st-4th grade',
    '5th-6th': '5th-6th grade',
    '7th-8th': '7th-8th grade',
    '9th': '9th grade',
    '10th': '10th grade',
    '11th': '11th grade',
    '12th': '12th grade',
    'HS-grad': 'High school graduate',
    'Some-college': 'Some college',
    'Assoc-voc': 'Associate degree (vocational)',
    'Assoc-acdm': 'Associate degree (academic)',
    'Bachelors': "Bachelor's degree",
    'Masters': "Master's degree",
    'Prof-school': 'Professional school degree',
    'Doctorate': 'Doctorate degree'
}

df['Education'] = df['Education'].replace(education_map)

# %%
#Now , let's check for duplicates...
df[df.duplicated()]
df.duplicated().sum()
#in the whole dataframe there are 24 duplicate in total..we can drop them..
# Out:
# np.int64(24)

# %% [markdown]
# **For this dataset, we can simply drop duplicates, because these are exact duplicate rows and there's no unique transaction/person ID telling us they represent legitimate repeated observations.there is nothing like one customer has done multiple transactions**

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Sanity Check for each feature**

# %%
df.describe()
# Out:
#                 Age  Final_census  Education-num  capital-gain  capital-loss  \
# count  32537.000000  3.253700e+04   32537.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.081815   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.571633   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# **In this dataset Final_census represent the fnlwgt(final weight) of the particular row i.e according to US census bureau it represent how many how many people in the population represent that row(like with same gender , race , education , etc)**

# %% [markdown]
# **For now let'see the correlation of final_census with each feature**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include='number').columns

corr = df[num_cols].corr()['Final_census'].sort_values(ascending=False)

plt.figure(figsize=(8, 6))
sns.barplot(x=corr.values, y=corr.index)
plt.title('Correlation with Final_census')
plt.xlabel('Correlation')
plt.show()

# %%
sns.heatmap(
  df[num_cols].corr(),
  annot=True,
  cmap='coolwarm',
  cbar = True,
  fmt = '.2f'
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **From above two plots we can say that final_census has a negative correlation with most feature so we can drop it**

# %%
df = df.drop(columns = ['Final_census'])

# %% [markdown]
# **Here we can see that Education , Education-num represent the same thing so , we can drop education while preserving Education-num which is simply representing ordinal values of Education thus Education-num is also ordinal**

# %%
df.groupby('Education')['Education-num'].value_counts()
# Out:
# Education                      Education-num
# 10th grade                     6                  933
# 11th grade                     7                 1175
# 12th grade                     8                  433
# 1st-4th grade                  2                  166
# 5th-6th grade                  3                  332
# 7th-8th grade                  4                  645
# 9th grade                      5                  514
# Associate degree (academic)    12                1067
# Associate degree (vocational)  11                1382
# Bachelor's degree              13                5353
# Doctorate degree               16                 413
# High school graduate           9                10494
# Master's degree                14                1722
# Preschool                      1                   50
# Professional school degree     15                 576
# Some college                   10                7282
# Name: count, dtype: int64

# %% [markdown]
# **Education is strongly associated with income in this dataset.**

# %%
educ_crosstab = pd.crosstab(df['Education'] , df['income'] , normalize='index')
print(educ_crosstab)
sns.heatmap(educ_crosstab , annot=True , cmap='viridis' , fmt='.2f')
plt.title('Education Crosstab VS Income')
plt.show()
# Out:
# income                            <=50K      >50K
# Education
# 10th grade                     0.933548  0.066452
# 11th grade                     0.948936  0.051064
# 12th grade                     0.923788  0.076212
# 1st-4th grade                  0.963855  0.036145
# 5th-6th grade                  0.951807  0.048193
# 7th-8th grade                  0.937984  0.062016
# 9th grade                      0.947471  0.052529
# Associate degree (academic)    0.751640  0.248360
# Associate degree (vocational)  0.738784  0.261216
# Bachelor's degree              0.585092  0.414908
# Doctorate degree               0.259080  0.740920
# High school graduate           0.840480  0.159520
# Master's degree                0.443089  0.556911
# Preschool                      1.000000  0.000000
# Professional school degree     0.265625  0.734375
# Some college                   0.809668  0.190332

# %%
df = df.drop(columns = ['Education'])

# %% [markdown]
# **Now , here after dropping Education , Final_Census , Unnamed:15 there are exactly 3441 duplicates(exact row)..which can cuase probelm like Data Lekage. So , we can remove them**

# %%
df.duplicated().sum()
# Out:
# np.int64(3441)

# %%
df[df.duplicated()]
df[df.duplicated(keep=False)]
# Out:
#        Age Profession Class  Education-num             marital-status  \
# 12      23   Private sector             13              Never-married
# 17      32   Private sector              9              Never-married
# 20      40   Private sector             16  Married (Civilian Spouse)
# 26      19   Private sector              9              Never-married
# 29      49   Private sector              9  Married (Civilian Spouse)
# ...    ...              ...            ...                        ...
# 32503   47   Private sector              9  Married (Civilian Spouse)
# 32512   20   Private sector              9              Never-married
# 32527   22   Private sector             10              Never-married
# 32557   40   Private sector              9  Married (Civilian Spouse)
# 32559   22   Private sector              9              Never-married
#
#                              occupation relationship   race  Gender  \
# ...

# %% [markdown]
# **Will only save first Occurence , and remove all the duplicate ones**

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## EDA(Univariate Analysis)

# %%
#Let's start with individual variables..
df
df['Age'].describe()
sns.histplot(df['Age'] , kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#now corresponding to age we can see how income variable is releated:
sns.boxplot(x='Age' , y='income' , data=df)
#high individual income have higher val of age
# Out:
# <Axes: xlabel='Age', ylabel='income'>

# %% [markdown]
# **Here we can see target column which is income(is imbalanced)**

# %%
#This is one of the FIRST EDA plots you should make in every classification problem.
#which is to see the target distribution..
df['income'].value_counts(normalize=True)
# Out:
# income
# <=50K    0.7522
# >50K     0.2478
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['Profession Class'] , df['income'] , normalize='index')
# Out:
# income                               <=50K      >50K
# Profession Class
# Federal-gov                       0.617336  0.382664
# Local government                  0.705392  0.294608
# Never worked                      1.000000  0.000000
# Private sector                    0.775903  0.224097
# Self-employed (incorporated)      0.445463  0.554537
# Self-employed (not incorporated)  0.713708  0.286292
# State government                  0.726415  0.273585
# Unknown                           0.884191  0.115809
# Without pay                       1.000000  0.000000

# %%
pd.crosstab(df['Education-num'] , df['income'] , normalize=True)
# Out:
# income            <=50K      >50K
# Education-num
# 1              0.001718  0.000000
# 2              0.005499  0.000206
# 3              0.010723  0.000550
# 4              0.020243  0.001375
# 5              0.016497  0.000928
# 6              0.027770  0.002028
# 7              0.034232  0.002062
# 8              0.013095  0.001134
# 9              0.254399  0.051004
# 10             0.175351  0.043855
# 11             0.033716  0.012029
# 12             0.027117  0.009073
# 13             0.097230  0.068085
# 14             0.025674  0.031138
# 15             0.005258  0.014194
# 16             0.003677  0.010139

# %%
occup_crosstab = pd.crosstab(df['occupation'] , df['income'] , normalize='index')
print(occup_crosstab)

sns.heatmap(
    occup_crosstab , 
    annot=True , 
    cmap='rocket' , 
    fmt='.2f'
)
plt.title('Occupation VS Income')
plt.show()
# Out:
# income                               <=50K      >50K
# occupation
# Adm-clerical                      0.855090  0.144910
# Armed-Forces                      0.888889  0.111111
# Craft-repair                      0.764099  0.235901
# Exec-managerial                   0.523259  0.476741
# Farming-fishing                   0.881497  0.118503
# Handlers and Cleaners             0.931298  0.068702
# Machine Operators and Inspectors  0.866040  0.133960
# Other Service                     0.954272  0.045728
# Private Household Service         0.993197  0.006803
# Professional Specialty            0.550579  0.449421
# Protective Service                0.678288  0.321712
# Sales                             0.723853  0.276147
# Technical Support                 0.692220  0.307780
# Transportation and Moving         0.790311  0.209689
# Unknown                           0.884686  0.115314

# %%
#we can see martial-status has also some relation with the income...
#rather than simply dropping it.
martial_status_crosstab = pd.crosstab(df['marital-status'] , df['income'] , normalize='index')
print(martial_status_crosstab)

sns.heatmap(
    martial_status_crosstab , 
    annot=True , 
    cmap='viridis' , 
    fmt='.2f'
)
plt.title('Martial Status VS Income')
plt.show()
# Out:
# income                            <=50K      >50K
# marital-status
# Divorced                       0.891433  0.108567
# Married (Armed Forces Spouse)  0.565217  0.434783
# Married (Civilian Spouse)      0.541777  0.458223
# Married-spouse-absent          0.918660  0.081340
# Never-married                  0.947127  0.052873
# Separated                      0.934911  0.065089
# Widowed                        0.914460  0.085540

# %%
pd.crosstab(df['relationship'] , df['income'] , normalize='index')
# Out:
# income             <=50K      >50K
# relationship
# Husband         0.537459  0.462541
# Not-in-family   0.889901  0.110099
# Other-relative  0.961658  0.038342
# Own-child       0.983643  0.016357
# Unmarried       0.934278  0.065722
# Wife            0.528796  0.471204

# %% [markdown]
# For some real-world applications, demographic attributes can create:
#
# -- fairness concerns
#
# -- discrimination risks
#
# -- regulatory issues

# %%
pd.crosstab(df['Gender'] , df['income'] , normalize='index')
# Out:
# income     <=50K      >50K
# Gender
# Female  0.883046  0.116954
# Male    0.685233  0.314767

# %% [markdown]
# there are huge values of 0..in both capital gain and capital loss...
# and the distribution is right skewed...some legitimate values are there not importantly the outlier

# %%
sns.histplot(df['capital-gain'] , bins = 50 , kde=True)
plt.show()

# %%
sns.histplot(df['capital-loss'], bins=50 , kde=True)
plt.show()

# %% [markdown]
# **we can also check zero vs non-zero count for both capital-gain , capital-loss**

# %%
capgain_zero = (df['capital-gain'] == 0).sum()
capgain_nzero = (df['capital-gain'] > 0).sum()

#sns.barplot(['0', 'Non-zero'] [capgain_zero , capgain_nzero]) ->nworking->i don know
plt.bar(['0', 'Non-zero'] , [capgain_zero , capgain_nzero])
plt.title("Capital Gain : Zero VS NonZero")
plt.ylabel('Count')
plt.show()

# %%
caploss_zero = (df['capital-loss'] == 0).sum()
caploss_nzero = (df['capital-loss'] > 0).sum()

#sns.barplot(['0', 'Non-zero'] [capgain_zero , capgain_nzero]) ->nworking->i don know
plt.bar(['0', 'Non-zero'] , [caploss_zero , caploss_nzero])
plt.title("Capital Loss : Zero VS NonZero")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **Outlier for all the numerical Individual features**

# %% [markdown]
# **So , Here when i have seen the outier value the values are some extreme observations but they are legitimate outliers...In this the Age is not something like -(something) or hours_per_week = 5000 rather it is 99..so the observation are meaningul..so i will simply keep these outliers.rather than removal**

# %%
num_cols = df.select_dtypes(include="number").columns

for col in num_cols:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75) # Corrected Q3 to be 0.75 for IQR calculation

  IQR = Q3 - Q1

  lower_bound = Q1 - 1.5*IQR
  upper_bound = Q3 + 1.5*IQR

  #see the outliers val..
  outliers = df[
    (df[col] < lower_bound) | (df[col] > upper_bound)
  ]

  #now , print them:
  print(col)
  print("Lower Bound: " , lower_bound)
  print("Upper Bound: " , upper_bound)
  print("Outliers: " , len(outliers))
  print()
# Out:
# Age
# Lower Bound:  -2.0
# Upper Bound:  78.0
# Outliers:  141
#
# Education-num
# Lower Bound:  3.0
# Upper Bound:  19.0
# Outliers:  216
#
# capital-gain
# Lower Bound:  0.0
# Upper Bound:  0.0
# Outliers:  2698
#
# capital-loss
# Lower Bound:  0.0
# Upper Bound:  0.0
# Outliers:  1511
#
# hours-per-week
# Lower Bound:  32.5
# Upper Bound:  52.5
# Outliers:  8476

# %% [markdown]
# Age shows a noticeable relationship with income in this dataset. Individuals earning more than 50K have a higher average age (44.25 years) compared with those earning 50K or less (36.78 years), and the median age also differs considerably (44 vs. 34 years). The box plot further confirms that the >50K income group is shifted toward higher ages. Although the IQR method identifies observations around 75–90 years as potential outliers, these represent realistic human ages rather than obvious data-entry errors. Therefore, these observations should not be removed solely because they are classified as statistical outliers.

# %%
sns.boxplot(x = df['income'] ,  y = df['Age'])
#now , let's find those values->
Q1 = np.quantile(df['Age'], 0.25)
Q3 = np.quantile(df['Age'], 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

print("Lower Bound is: " , lower_bound , "Upper Bound is: " , upper_bound)
# Out:
# Lower Bound is:  -2.0 Upper Bound is:  78.0

# %%
sns.boxplot(x = df['income'] , y = df['Education-num'])
Q1 = np.quantile(df['Education-num'], 0.25)
Q3 = np.quantile(df['Education-num'], 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
print("Lower Bound is: " , lower_bound , "Upper Bound is: " , upper_bound)
# Out:
# Lower Bound is:  3.0 Upper Bound is:  19.0

# %%
df
# Out:
#        Age                  Profession Class  Education-num  \
# 0       39                  State government             13
# 1       50  Self-employed (not incorporated)             13
# 2       38                    Private sector              9
# 3       53                    Private sector              7
# 4       28                    Private sector             13
# ...    ...                               ...            ...
# 32554   53                    Private sector             14
# 32555   22                    Private sector             10
# 32556   27                    Private sector             12
# 32558   58                    Private sector              9
# 32560   52      Self-employed (incorporated)              9
#
#                   marital-status              occupation   relationship  \
# 0                  Never-married            Adm-clerical  Not-in-family
# 1      Married (Civilian Spouse)         Exec-managerial        Husband
# ...

# %%
sns.boxplot(x = df['income'] , y = df['hours-per-week'])
Q1 = np.quantile(df['hours-per-week'], 0.25)
Q3 = np.quantile(df['hours-per-week'], 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
print("Lower Bound is: " , lower_bound , "Upper Bound is: " , upper_bound)
# Out:
# Lower Bound is:  32.5 Upper Bound is:  52.5

# %% [markdown]
# ### Model Training

# %%
X = df.drop(columns = ['income'])
y = df['income']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(
  X,
  y,
  test_size = 0.20,
  random_state = 42,
  stratify=y         #we want the same ratio in both train and test...76% <=50K and 24% >50K
)

# %% [markdown]
# **FOR NO Data Lekage**
#
# Raw data
#
#    ↓
#
# Basic cleaning
#
#    ↓
#
# Train/Test Split
#
#    ↓
#
# Fit preprocessing on TRAIN only
#
#    ↓
#
# Transform TRAIN
# Transform TEST
#
#    ↓
#
# Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler , OneHotEncoder

# %%
numeric_cols = [
  "Age",
  "Education-num",
  "capital-gain",
  "capital-loss",
  "hours-per-week"
]

categorical_cols = [
  "Profession Class",
  "marital-status",
  "occupation",
  "relationship",
  #"race",
  "Gender",
  "country"
]

# %%
#for logistic regression we will use StandardScaler for numerical features and OneHotEncoder for categorical features.
numeric_transformer_lr = Pipeline([
  ("imputer", SimpleImputer(strategy="median")),
  ("scaler", StandardScaler())
])

# %%
# For Tree-based models
numeric_transformer_tree = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

# %%
#numeric_pipeline

# %%
categorical_pipeline = Pipeline([
  ("imputer", SimpleImputer(strategy="most_frequent")),
  ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# %%
categorical_pipeline
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor_lr = ColumnTransformer([
  ("num", numeric_transformer_lr, numeric_cols),
  ("cat", categorical_pipeline, categorical_cols)
])

# %%
preprocessor_tree = ColumnTransformer([
    ("num", numeric_transformer_tree, numeric_cols),
    ("cat", categorical_pipeline, categorical_cols)
])

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = Pipeline([
  ("preprocessor" , preprocessor_lr),
  ("model" , LogisticRegression(
    max_iter = 2000
  ))
])
logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Education-num',
#                                                    'capital-gain',
#                                                    'capital-loss',
#                                                    'hours-per-week']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
#now , for the prediction:
y_pred = logistic_model.predict(X_test)

# %% [markdown]
# ### Evaluate it

# %%
from sklearn.metrics import(
  accuracy_score,
  precision_score,
  recall_score,
  f1_score,  #for the minority class , thus making precision and recall balanced
  roc_auc_score,
  confusion_matrix,
  classification_report
)

print("accuracy : " , accuracy_score(y_test , y_pred))
#we have to pass the positive class label as precision and recall , f1 score need the positive label
#so u have to pass the positive label as in our case it's >50k....pos_label = 1
print("precision_score : " , precision_score(y_test , y_pred, pos_label='>50K'))
print("recall_score : " , recall_score(y_test , y_pred, pos_label='>50K'))
print("f1_score :", f1_score(y_test, y_pred, pos_label='>50K'))
print(logistic_model.classes_)
#predict the probability of the second class....so it will give the probability for both <=50k,>50k
y_prob = logistic_model.predict_proba(X_test)[:,1]
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
# Out:
# accuracy :  0.845360824742268
# precision_score :  0.7239669421487603
# recall_score :  0.6074895977808599
# f1_score : 0.6606334841628959
# ['<=50K' '>50K']
# ROC-AUC: 0.9039796923084722

# %%
#confusion_matrix
cm = confusion_matrix(y_test , y_pred)

sns.heatmap(
  cm,
  annot = True,
  cmap = 'viridis',
  fmt = '.2f'
)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# Raw X_train
#
#     ↓
# Imputation
#
#
#     ↓
# One-Hot Encoding
#
#     ↓
#
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = Pipeline([
  ("preprocessor" , preprocessor_tree),
  ("model" , DecisionTreeClassifier(
    max_depth=10,
    min_samples_leaf=4,
    random_state = 42
  ))
])

dt_model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Age', 'Education-num',
#                                                    'capital-gain',
#                                                    'capital-loss',
#                                                    'hours-per-week']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %%
y_pred_dt = dt_model.predict(X_test)

y_prob_dt = dt_model.predict_proba(X_test)[:,1]

print("Decision Tree Metrics")
print("accuracy: " , accuracy_score(y_test , y_pred_dt))
print("precision: " , precision_score(y_test , y_pred_dt , pos_label = '>50K'))
print("recall: " , recall_score(y_test , y_pred_dt , pos_label = '>50K'))
print("f1_score: " , f1_score(y_test , y_pred_dt , pos_label = '>50K'))
print("roc-auc: " , roc_auc_score(y_test , y_prob_dt))
# Out:
# Decision Tree Metrics
# accuracy:  0.8587628865979381
# precision:  0.7782764811490126
# recall:  0.6012482662968099
# f1_score:  0.6784037558685446
# roc-auc:  0.903154975482633

# %%
cm = confusion_matrix(y_test , y_pred_dt)

sns.heatmap(
  cm,
  annot = True,
  cmap = 'magma',
  fmt = '.2f'
)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Decision Tree Confusion Matrix")
plt.show()

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = Pipeline([
  ("preprocessor" , preprocessor_tree),
  ("model" , RandomForestClassifier(
    n_estimators = 500,
    min_samples_leaf = 4,
    max_features = 'sqrt',
    #class_weight = "balanced", ->lowering the accuracy , precision , recall , roc-auc
    random_state = 42,
    n_jobs=-1
  )),
])
rf_model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Age', 'Education-num',
#                                                    'capital-gain',
#                                                    'capital-loss',
#                                                    'hours-per-week']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %% [markdown]
# Random Forest Beat Logistic Regression due to the ability of capturing non linear relationships....not like logReg..makes simple decision boundary..

# %%
from sklearn.metrics import(
  accuracy_score,
  precision_score,
  recall_score,
  f1_score,
  roc_auc_score,
  confusion_matrix,
  classification_report
)

#make predictions using the Random Forest model
y_pred_rf = rf_model.predict(X_test)
# Predict probabilities using the Random Forest model
#y_prob_rf = rf_model.predict_proba(X_test)[:,1]

y_prob_rf = rf_model.predict_proba(X_test)[:,1]

print("Random Forest Model Metrics:")
print("accuracy : " , accuracy_score(y_test , y_pred_rf))
print("precision_score : " , precision_score(y_test , y_pred_rf, pos_label='>50K'))
print("recall_score : " , recall_score(y_test , y_pred_rf, pos_label='>50K'))
print("f1_score :", f1_score(y_test, y_pred_rf, pos_label='>50K'))
# print(rf_model.classes_) # The classes should be the same as logistic_model.classes_
print("ROC-AUC:", roc_auc_score(y_test, y_prob_rf))
# Out:
# Random Forest Model Metrics:
# accuracy :  0.8601374570446736
# precision_score :  0.7823741007194245
# recall_score :  0.6033287101248266
# f1_score : 0.6812842599843383
# ROC-AUC: 0.9172972097912333

# %%
cm = confusion_matrix(y_test , y_pred_rf)

sns.heatmap(
  cm,
  annot = True,
  cmap = 'viridis',
  fmt = '.2f'
)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ### Prediction ≠ causality.

# %% [markdown]
# ### HyperParameter Tuning for Random Forst

# %%
param_grid = {
  "model__n_estimators":[200,300,500],
  "model__max_depth":[None , 10 , 20],
  "model__min_samples_leaf":[1,2,4],
  "model__max_features":["sqrt", "log2"]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

search = RandomizedSearchCV(
  rf_model,
  param_distributions = param_grid,
  n_iter = 10,
  scoring = "f1",
  #instead of one_train/validation set will make multiple folds
  cv=3,
  random_state = 42,
  n_jobs = -1
)

search.fit(X_train , y_train)
# Out:
# c:\Users\Herpreet Singh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median'))]),
#                                                                                ['Age',
#                                                                                 'Education-num',
#                                                                                 'capital-gain',
# ...

# %%
print("Best Parameters:")
print(search.best_params_)

print("\nBest CV F1 Score:")
print(search.best_score_)
# Out:
# Best Parameters:
# {'model__n_estimators': 300, 'model__min_samples_leaf': 1, 'model__max_features': 'sqrt', 'model__max_depth': 10}
#
# Best CV F1 Score:
# nan

# %%
#best tuned model nikalo
best_rf = search.best_estimator_

# %%
y_pred_rf_tuned = best_rf.predict(X_test)

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix
)

y_prob_rf_tuned = best_rf.predict_proba(X_test)[:,1]

print("Accuracy:", accuracy_score(y_test, y_pred_rf_tuned))
print("Precision:", precision_score(y_test, y_pred_rf_tuned , pos_label = '>50K'))
print("Recall:", recall_score(y_test, y_pred_rf_tuned , pos_label = '>50K'))
print("F1:", f1_score(y_test, y_pred_rf_tuned , pos_label = '>50K'))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_rf_tuned))
# Out:
# Accuracy: 0.8553264604810996
# Precision: 0.808641975308642
# Recall: 0.5450762829403606
# F1: 0.6512013256006628
# ROC-AUC: 0.9118569141255388
